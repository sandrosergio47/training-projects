# %% [markdown]
# **Декомпозиция:**
#
# - загрузка данных;
# - предобработка данных (обработка пропущенных значений, преобразование типов данных, поиск явных дубликатов и т.д.);
# - составить профиль пользователей с датой первого входа в приложение;
# - рассчитать затраты на рекламу по каждому каналу;
# - рассчитать сколько стоит привлечение одного пользователя (среднее и по каждому рекламному каналу);
# - произвести категорирование пользователей на: 'не завершил уровень', 'завершил уровень с выполненным проектом' и 'завершил уровень без выполненного проекта';
# - рассчитать количество пользователей, которые закончили первый уровень и которые забросили игру;
# - рассчитать средние значения количества построек для пользователей, которые завершили первый уровень, и пользователей, которые забросили игру;
# - вероятно, где-то на этом этапе я пойму, что событие, которое влияет на совершение целевого события - количество построек каждым пользователем (данных мало, и я пока не вижу что это ещё может быть);
# - когда я увижу какое количество построек выполняет каждый пользователь в среднем, я смогу предложить модель монетизации, чтобы реклама окупалась. Как я это вижу: "на какой по счету постройке пользователю необходимо показывать рекламу, чтобы отбить 0,57 (средняя стоимость привлечения одного пользователя);
# - далее, мне нужно будет посчитать разницу во времени между первым входом пользователя и последним событием этого пользователя;
# - формулировка и проверка гипотезы о равенстве среднего количества затраченного времени на прохождение первого уровня для пользователей, которые завершили проект и пользователей, которые не завершили проект;
# - предварительно, вторая гипотеза будет о равенстве среднего количества построек для пользователей, которые завершили проект и пользователей, которые не завершили проект;
# - оценка модели монетизации.
